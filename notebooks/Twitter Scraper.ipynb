# %%
#Import needed libraries
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# # Scrape tweets based on KEYWORDS and DATE

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('DUP since:2022-01-01 until:2022-05-10 near:"Bangor" within:10km').get_items()):
    if i>1500:
        break
        #We define the meta we want to save from the scraped tweets
    tweets_list.append(tweet.content)
    
tweets_list
# Out:
# ['@J_Donaldson_MP You and the MLAs you lead are a disgrace.\nIf you and @duponline are to be seen as principled - do not take your salaries - or claim them for you, your offices, family secretaries and SPADs and donate to @WomensAidAD @samaritansbmena @mensaidNI \nMake a difference for once',
#  '@jon_ni72 @mooreholmes24 @duponline RHI / DUP say no more!!',
#  "@JamieBrysonCPNI Mate, Unionism has called the title 'First minister' for years and years.\n\nWith McGuinness and O'Neill serving as deputies..\n\nI even think there was an amendment in Westminster in January, which would have called it 'Joint minister'.\n\nSomething the DUP voted against?..",
#  '@RichardBullick1 @peterdonaghy I saw reference elsewhere to 578, and that may have been on the assumption that no SDLP transfers came to the dup. The eliminated tuv candidate had around 2700 when eliminated- just over 2100 transferred. Starting point for the tuv candidate was just over 2400. SDLP had 2600ish',
# ...

# %%
#Sort by number of retweets, likes, replies, or quotes
df_tweets.sort_values('Likes', ascending=False)
# Out:
#                         Datetime             Tweet Id  \
# 19563  2020-01-30 15:36:42+00:00  1222906492413784064
# 21013  2019-12-27 10:55:16+00:00  1210514478086971392
# 29052  2019-05-31 18:13:21+00:00  1134523273994260480
# 39546  2018-07-14 17:00:01+00:00  1018178315696427008
# 27634  2019-06-27 17:45:38+00:00  1144300770067660800
# ...                          ...                  ...
# 49824  2017-10-10 21:12:08+00:00   917860320751874055
# 49825  2017-10-10 20:43:56+00:00   917853226359066624
# 49826  2017-10-10 20:00:03+00:00   917842181947346945
# 49827  2017-10-10 19:30:24+00:00   917834718640529410
# 103098 2012-01-01 03:39:34+00:00   153319426517774337
#
#                                                      Text  \
# 19563   Ich habe 3 Kinder (16,15 + 13) auf 2 Gymnasien...
# 21013   This morning I visited sites of urban vertical...
# 29052   Vertical farming 🥬\nhttps://t.co/NWkD5o0Zt6 ht...
# 39546   Data-infused #VerticalFarming is redefining #a...
# ...

# %%
#Select tweets based on minimum number of retweets, likes, replies, or quotes
df_tweets[df_tweets['Likes']>=900]
# Out:
#                        Datetime             Tweet Id  \
# 19563 2020-01-30 15:36:42+00:00  1222906492413784064
# 21013 2019-12-27 10:55:16+00:00  1210514478086971392
# 27634 2019-06-27 17:45:38+00:00  1144300770067660800
# 29052 2019-05-31 18:13:21+00:00  1134523273994260480
# 39546 2018-07-14 17:00:01+00:00  1018178315696427008
#
#                                                     Text  \
# 19563  Ich habe 3 Kinder (16,15 + 13) auf 2 Gymnasien...
# 21013  This morning I visited sites of urban vertical...
# 27634  5/ One guy tried to pitch to me his vertical f...
# 29052  Vertical farming 🥬\nhttps://t.co/NWkD5o0Zt6 ht...
# 39546  Data-infused #VerticalFarming is redefining #a...
#
#                         Content links  Retweets  Likes  Replies  Quotes  \
# 19563                              []       697   2611      371      94
# 21013                              []       151   1571      170      36
# 27634                              []       186    921       12       7
# ...

# %%
#Select tweets based on Username
df_tweets[df_tweets['Username'].isin([ "verticalgrower"])]
# Out:
#                        Datetime             Tweet Id  \
# 24300 2019-09-30 16:51:01+00:00  1178713875333693440
# 24329 2019-09-29 22:57:00+00:00  1178443590265184257
# 24366 2019-09-27 22:57:01+00:00  1177718817339924480
# 24379 2019-09-27 17:08:02+00:00  1177630991197917185
# 24460 2019-09-25 17:08:03+00:00  1176906221317697536
# ...                         ...                  ...
# 63870 2016-11-30 19:17:14+00:00   804041615216148485
# 63971 2016-11-28 15:07:13+00:00   803253920608894976
# 64031 2016-11-25 23:40:11+00:00   802295850814832640
# 64103 2016-11-23 14:23:14+00:00   801430916044296193
# 64189 2016-11-21 07:08:11+00:00   800596653602324480
#
#                                                     Text  \
# 24300  Here's how to learn more about vertical farmin...
# 24329  The pros and cons of vertical farming: https:/...
# 24366  An easy way to learn more about vertical farmi...
# 24379  Vertical Farming (How does it work?): https://...
# ...

# %%
#Count number of tweets based on Username
df_tweets['Username'].value_counts()
# Out:
# UFninja           2548
# SEEDSandCHIPS      843
# BrightAgrotech     843
# federicogoria      591
# verticalgrower     587
#                   ...
# YannWeb              1
# alealfaro89          1
# _stockhoncho2X       1
# charlesmire          1
# chiriottied          1
# Name: Username, Length: 41982, dtype: int64

# %%
#List tweets countaining a specific keyword or username
df_tweets[df_tweets['Text'].str.contains("AbiyAhmedAli")]
# Out:
#                        Datetime             Tweet Id  \
# 15999 2020-05-07 10:29:40+00:00  1258343234822176768
# 20951 2019-12-29 05:42:10+00:00  1211160459036053504
# 20952 2019-12-29 05:29:22+00:00  1211157239173722112
# 20976 2019-12-28 06:24:42+00:00  1210808776141332483
# 20993 2019-12-27 18:10:48+00:00  1210624082993176576
# 21002 2019-12-27 14:21:52+00:00  1210566468988997632
# 21011 2019-12-27 11:29:09+00:00  1210523003504775168
#
#                                                     Text  \
# 15999  Enjoy a short video on #vertical #farming in #...
# 20951  @AertsJens @AbiyAhmedAli @oikos_solutions @Ele...
# 20952  @AbiyAhmedAli Vertical farming and roof farmin...
# 20976  @AbiyAhmedAli @aswagalmal @yassin_salam \nShoo...
# 20993  @AbiyAhmedAli Our beloved PM, It would have be...
# 21002  @AbiyAhmedAli our cities are invading fertile ...
# 21011  @AbiyAhmedAli Focusing on urban vertical farmi...
#
# ...

# %% [markdown]
# # Scrape tweets based on USERNAME

# %%
# Creating list to append tweet data to
tweets_user_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:potus').get_items()):
    if i>100:
        break
    tweets_user_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
    
# Creating a dataframe from the tweets list above 
df_user_tweets = pd.DataFrame(tweets_user_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
df_user_tweets.to_csv('verticalfarming-user-tweets.csv',index = False, encoding='utf-8')
df_user_tweets

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bf1f20fb-a6c0-4ea2-8567-a5a41eea1d8a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
